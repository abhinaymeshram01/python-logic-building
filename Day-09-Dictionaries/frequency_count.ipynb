# %%
arr = list(map(int, input("Enter elements: ").split()))
freq = {}

for num in arr:
    freq[num] = freq.get(num, 0) + 1

print(freq)
# Out:
# Enter elements:  12 3 5  6545
# {12: 1, 3: 1, 5: 1, 6545: 1}
