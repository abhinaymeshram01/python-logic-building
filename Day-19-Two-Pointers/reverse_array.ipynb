# %%
arr = list(map(int, input("Enter numbers: ").split()))
left, right = 0, len(arr) - 1

while left < right:
    arr[left], arr[right] = arr[right], arr[left]
    left += 1
    right -= 1

print("Reversed array:", arr)
# Out:
# Enter numbers:  12 34 56 78
# Reversed array: [78, 56, 34, 12]
