# %%
queue = []

def enqueue(x):
    queue.append(x)

def dequeue():
    if not queue:
        print("Queue Underflow")
    else:
        return queue.pop(0)

enqueue(10)
enqueue(20)
print(dequeue())  # 10
# Out:
# 10
