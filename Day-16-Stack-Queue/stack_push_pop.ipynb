# %%
stack = []

def push(x):
    stack.append(x)

def pop():
    if not stack:
        print("Stack Underflow")
    else:
        return stack.pop()

push(10)
push(20)
print(pop())   # 20
# Out:
# 20
