# %%
class Book:
    def __init__(self, title, price):
        self.title = title
        self.price = price

    def __str__(self):
        return f"{self.title} costs {self.price}"


b = Book("Python Basics", 299)
print(b)
# Out:
# Python Basics costs 299
