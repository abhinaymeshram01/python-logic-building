# %%
with open("data.txt", "w") as file:
    file.write("Day 12: File handling in Python\n")
    file.write("Learning step by step\n")

print("Data written successfully")
# Out:
# Data written successfully
