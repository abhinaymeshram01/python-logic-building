# %%
arr = list(map(int, input("Enter numbers: ").split()))

n = len(arr)
for i in range(n):
    min_idx = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_idx]:
            min_idx = j
    arr[i], arr[min_idx] = arr[min_idx], arr[i]

print("Sorted array:", arr)
# Out:
# Enter numbers:  12 34 56
# Sorted array: [12, 34, 56]
