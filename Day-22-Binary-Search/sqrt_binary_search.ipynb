# %%
n = int(input("Enter number: "))

left, right = 0, n
ans = 0

while left <= right:
    mid = (left + right) // 2

    if mid * mid <= n:
        ans = mid
        left = mid + 1
    else:
        right = mid - 1

print("Square root:", ans)
# Out:
# Enter number:  64
# Square root: 8
