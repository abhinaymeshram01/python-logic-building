# %%
arr = list(map(int, input("Enter numbers: ").split()))
seen = set()
duplicates = set()

for num in arr:
    if num in seen:
        duplicates.add(num)
    else:
        seen.add(num)

print("Duplicates:", duplicates)
# Out:
# Enter numbers:  12 34 56 78
# Duplicates: set()
