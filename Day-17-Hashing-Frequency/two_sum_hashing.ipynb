# %%
arr = list(map(int, input("Enter numbers: ").split()))
target = int(input("Enter target: "))

seen = {}

for num in arr:
    rem = target - num
    if rem in seen:
        print(rem, num)
        break
    seen[num] = True
# Out:
# Enter numbers:  12 34 56 78
# Enter target:  23
