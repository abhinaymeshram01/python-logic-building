# %%
def insert_bst(root, key):
    if not root:
        return TreeNode(key)

    if key < root.data:
        root.left = insert_bst(root.left, key)
    else:
        root.right = insert_bst(root.right, key)

    return root
