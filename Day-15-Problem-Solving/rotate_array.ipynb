# %%
arr = list(map(int, input("Enter numbers: ").split()))
k = int(input("Enter rotations: "))

k %= len(arr)
rotated = arr[k:] + arr[:k]

print("Rotated array:", rotated)
# Out:
# Enter numbers:  12 34 56 78
# Enter rotations:  2
# Rotated array: [56, 78, 12, 34]
