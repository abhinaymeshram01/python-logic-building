# %%
arr = list(map(int, input("Enter elements: ").split()))
rev = []

for i in range(len(arr)-1, -1, -1):
    rev.append(arr[i])

print("Reversed list:", rev)
# Out:
# Enter elements:  12 3 45 6
# Reversed list: [6, 45, 3, 12]
