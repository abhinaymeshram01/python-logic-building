# %%
arr = list(map(int, input("Enter elements: ").split()))
unique = []

for num in arr:
    if num not in unique:
        unique.append(num)

print("Without duplicates:", unique)
# Out:
# Enter elements:  34 65 87 4 5 6
# Without duplicates: [34, 65, 87, 4, 5, 6]
