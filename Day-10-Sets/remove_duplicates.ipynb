# %%
arr = list(map(int, input("Enter elements: ").split()))
seen = set()
result = []

for num in arr:
    if num not in seen:
        seen.add(num)
        result.append(num)

print("Without duplicates:", result)
# Out:
# Enter elements:  12 34 12 56 34
# Without duplicates: [12, 34, 56]
