# %%
arr = list(map(int, input("Enter elements: ").split()))

if len(arr) != len(set(arr)):
    print("Duplicates exist")
else:
    print("No duplicates")
# Out:
# Enter elements:  12 34 5 67
# No duplicates
