# %%
a = set(map(int, input("Enter first list: ").split()))
b = set(map(int, input("Enter second list:").split()))

print("Union:", list(a | b))
print("Difference (A - B):", list(a - b))
# Out:
# Enter first list:  12 34 56 78
# Enter second list: 12 34 56 78
# Union: [34, 12, 78, 56]
# Difference (A - B): []
