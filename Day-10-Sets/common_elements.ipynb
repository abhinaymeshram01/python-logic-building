# %%
a = list(map(int, input("Enter first list: ").split()))
b = list(map(int, input("Enter second list: ").split()))

common = set(a) & set(b)
print("Common elements:", list(common))
# Out:
# Enter first list:  12 34 56 78
# Enter second list:  12 34 56 78
# Common elements: [56, 34, 12, 78]
